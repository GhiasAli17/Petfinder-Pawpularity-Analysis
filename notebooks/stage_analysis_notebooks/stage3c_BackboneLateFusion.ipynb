# %% [markdown]
# > In this stage, swin image backbone vs swin + effB4 late fusion are compared, but the overall performance is not much improved indicating that SWIN already captures the enough pattern learned by EfficientNet

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.insert(0, os.path.abspath("../.."))

# %% [markdown]
# ### 1. SWIN only vs SWIN + EffB4 Late Fusion

# %%
from src.plot import compare_oof_by_bins
bins = [0, 20, 40, 60, 80, 100]

df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
    oof_path_a="../../outputs/exp3/oof_detail.csv",
    oof_path_b="../../outputs/exp9/oof_detail.csv",
    bins=bins,
    label_a="Exp3_swin_NoFusion",
    label_b="Exp9_swin+EffB4_late_Fusion",
    title_prefix="SWIN vs SWIN+EffB4 Late Fusion",)
# Out:
# Exp3_swin_NoFusion OOF RMSE: 17.714745225456582
# Exp9_swin+EffB4_late_Fusion OOF RMSE: 17.598341294670554
# ΔRMSE (Exp9_swin+EffB4_late_Fusion - Exp3_swin_NoFusion): -0.11640393078602784

# %%
df_bins.head()
# Out:
#          bin  count  Exp3_swin_NoFusion_rmse  \
# 0    (0, 20]   1417                24.496437
# 1   (20, 40]   5119                 9.970236
# 2   (40, 60]   2088                13.859223
# 3   (60, 80]    727                24.577702
# 4  (80, 100]    561                40.300325
#
#    Exp9_swin+EffB4_late_Fusion_rmse  rmse_diff  \
# 0                         23.895821  -0.600616
# 1                          9.245733  -0.724504
# 2                         13.501655  -0.357568
# 3                         25.228700   0.650998
# 4                         41.789151   1.488826
#
#                                winner
# 0  Exp9_swin+EffB4_late_Fusion_better
# 1  Exp9_swin+EffB4_late_Fusion_better
# 2  Exp9_swin+EffB4_late_Fusion_better
# 3           Exp3_swin_NoFusion_better
# 4           Exp3_swin_NoFusion_better
