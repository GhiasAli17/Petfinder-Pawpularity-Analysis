# %% [markdown]
# ## Architecture
# In this architecuter, first feature are extracted through the finetuned EfficieneNetB1 and then additional 4 FiLMed block added where each block consist of convolutional layer, Batch Norm layer, activation (Relu), and inside each block FiLM layer is applied on feature maps/channels. This is not direct internal backbone feature modulation, rather it is additional layer on the top of extracted features from the finetuned backbone.
#
# ![image.png](attachment:image.png)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.insert(0, os.path.abspath("../.."))

# %%
# Cell 1: imports & setup
import os, time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gc

gc.enable()

import torch
from torch.utils.data import DataLoader
from sklearn.model_selection import KFold
from sklearn.metrics import root_mean_squared_error

from src.config import EXP_CONFIGS
from src.utils import set_seed, save_config
from src.data import build_transforms, ImageTabDataset
from src.models import FeatureConcatFusionNet, build_vision_backbone
from src.film import FiLMExternalModulation



main_folder = "../.."
data_csv = os.path.join(main_folder, "data", "train.csv")
img_folder = os.path.join(main_folder, "data", "train")
out_dir = os.path.join(main_folder, "outputs","extra", "exp12_film_fusion_EfficientNetB1_ExternalModulation_UnFreezeBackbone")   # 

df = pd.read_csv(data_csv)
cfg = EXP_CONFIGS["exp12_film"]   # define in config
cfg["name"] = "exp12_film_fusion_ExternalModulation_UnFreezeBackbone_EffB1"

TARGET = "Pawpularity"
tab_cols = [c for c in df.columns if c not in ["Id", TARGET]]

os.makedirs(out_dir, exist_ok=True)
save_config(cfg, out_dir)
set_seed(cfg["seed"])
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import root_mean_squared_error
from src.train import run_single_fold

kf = KFold(n_splits=cfg["n_splits"], shuffle=True, random_state=cfg["seed"])
oof_pred = np.zeros(len(df))
oof_true = df[TARGET].values
fold_index = np.full(len(df), -1, dtype=int)
fold_rmse = []

start_all = time.time()
for fold, (tr_idx, val_idx) in enumerate(kf.split(df), start=1):
    print(f"\n=== {cfg['name']}: Fold {fold} ===")
    train_df = df.iloc[tr_idx].reset_index(drop=True)
    val_df   = df.iloc[val_idx].reset_index(drop=True)

    best_rmse, val_preds, val_targets, val_ids = run_single_fold(
    fold=fold,
    train_df=train_df,
    val_df=val_df,
    img_folder=img_folder,
    cfg=cfg,
    out_dir=out_dir,
    device=device,
    mode="film_stack_effb1",   # <--- use FiLMExternalModulation    branch
    tab_cols=tab_cols,
    workers=16,
    pin_memory=True,
    persistent_workers=True,
    freeze_backbone=False,   # True => freeze EfficientNet-B1 backbone, False => finetune EfficientNet-B1
)

    oof_pred[val_idx] = val_preds
    fold_index[val_idx] = fold
    fold_rmse.append(best_rmse)
    print(f"Fold {fold} best RMSE: {best_rmse:.4f}")

all_sec = time.time() - start_all
print(f"\nTotal training time: {int(all_sec//60)}m {int(all_sec%60)}s")
# final metrics + OOF with fold column
oof_rmse = root_mean_squared_error(oof_true, oof_pred)
fold_rmse = np.array(fold_rmse)
print(f"\nOOF RMSE: {oof_rmse:.4f}")
print(f"Fold RMSEs: {fold_rmse.tolist()}  Mean={fold_rmse.mean():.4f}  Std={fold_rmse.std():.4f}")

oof_df = pd.DataFrame({
    "Id": df["Id"],
    "fold": fold_index,     
    "ytrue": oof_true,
    "oof_pred": oof_pred,
})
oof_df["abs_err"] = (oof_df["ytrue"] - oof_df["oof_pred"]).abs()
oof_df.to_csv(os.path.join(out_dir, "oof_detail.csv"), index=False)
oof_df.sort_values("abs_err", ascending=False).head(50).to_csv(
    os.path.join(out_dir, "top50_errors.csv"), index=False
)

np.save(os.path.join(out_dir, "oof_pred.npy"), oof_pred)
np.save(os.path.join(out_dir, "fold_rmse.npy"), fold_rmse)
with open(os.path.join(out_dir, "metrics.txt"), "w") as f:
    f.write(f"OOF_RMSE: {oof_rmse:.4f}\n")
    f.write(f"Fold_RMSE: {fold_rmse.tolist()}\nMean: {fold_rmse.mean():.4f}\nStd: {fold_rmse.std():.4f}\n")
# Out:
# === exp12_film_fusion_ExternalModulation_UnFreezeBackbone_EffB1: Fold 1 ===
# Epoch 1/10 | Fold 1 | Train[MSE]: RMSE=28.8447 | ValRMSE: 19.4759
# Epoch 2/10 | Fold 1 | Train[MSE]: RMSE=17.7289 | ValRMSE: 19.1770
# Epoch 3/10 | Fold 1 | Train[MSE]: RMSE=15.7521 | ValRMSE: 19.5024
# Epoch 4/10 | Fold 1 | Train[MSE]: RMSE=13.5888 | ValRMSE: 19.7744
# Epoch 5/10 | Fold 1 | Train[MSE]: RMSE=11.5381 | ValRMSE: 19.9565
# Epoch 6/10 | Fold 1 | Train[MSE]: RMSE=10.1856 | ValRMSE: 20.0360
# Epoch 7/10 | Fold 1 | Train[MSE]: RMSE=9.1842 | ValRMSE: 20.1641
# Early stopping at epoch 7
# Fold 1 best RMSE: 19.1770
#
# === exp12_film_fusion_ExternalModulation_UnFreezeBackbone_EffB1: Fold 2 ===
# Epoch 1/10 | Fold 2 | Train[MSE]: RMSE=29.6882 | ValRMSE: 19.0289
# Epoch 2/10 | Fold 2 | Train[MSE]: RMSE=18.1987 | ValRMSE: 18.9927
# Epoch 3/10 | Fold 2 | Train[MSE]: RMSE=16.1135 | ValRMSE: 20.2410
# Epoch 4/10 | Fold 2 | Train[MSE]: RMSE=13.3767 | ValRMSE: 20.2341
# Epoch 5/10 | Fold 2 | Train[MSE]: RMSE=11.3467 | ValRMSE: 20.2988
# Epoch 6/10 | Fold 2 | Train[MSE]: RMSE=10.2268 | ValRMSE: 20.9963
# Epoch 7/10 | Fold 2 | Train[MSE]: RMSE=9.1822 | ValRMSE: 20.4115
# Early stopping at epoch 7
# Fold 2 best RMSE: 18.9927
#
# === exp12_film_fusion_ExternalModulation_UnFreezeBackbone_EffB1: Fold 3 ===
# Epoch 1/10 | Fold 3 | Train[MSE]: RMSE=28.7834 | ValRMSE: 18.4025
# Epoch 2/10 | Fold 3 | Train[MSE]: RMSE=17.8053 | ValRMSE: 18.3068
# Epoch 3/10 | Fold 3 | Train[MSE]: RMSE=15.4090 | ValRMSE: 18.9040
# Epoch 4/10 | Fold 3 | Train[MSE]: RMSE=13.3076 | ValRMSE: 19.3214
# Epoch 5/10 | Fold 3 | Train[MSE]: RMSE=11.1616 | ValRMSE: 19.1315
# Epoch 6/10 | Fold 3 | Train[MSE]: RMSE=10.0653 | ValRMSE: 19.5307
# Epoch 7/10 | Fold 3 | Train[MSE]: RMSE=9.0555 | ValRMSE: 19.4965
# Early stopping at epoch 7
# Fold 3 best RMSE: 18.3068
#
# === exp12_film_fusion_ExternalModulation_UnFreezeBackbone_EffB1: Fold 4 ===
# Epoch 1/10 | Fold 4 | Train[MSE]: RMSE=28.6163 | ValRMSE: 18.6924
# Epoch 2/10 | Fold 4 | Train[MSE]: RMSE=17.8034 | ValRMSE: 18.5727
# Epoch 3/10 | Fold 4 | Train[MSE]: RMSE=15.7104 | ValRMSE: 18.9180
# Epoch 4/10 | Fold 4 | Train[MSE]: RMSE=13.2545 | ValRMSE: 18.9983
# Epoch 5/10 | Fold 4 | Train[MSE]: RMSE=11.3644 | ValRMSE: 19.5177
# Epoch 6/10 | Fold 4 | Train[MSE]: RMSE=10.1563 | ValRMSE: 19.4550
# Epoch 7/10 | Fold 4 | Train[MSE]: RMSE=9.1288 | ValRMSE: 19.6620
# Early stopping at epoch 7
# Fold 4 best RMSE: 18.5727
#
# === exp12_film_fusion_ExternalModulation_UnFreezeBackbone_EffB1: Fold 5 ===
# Epoch 1/10 | Fold 5 | Train[MSE]: RMSE=29.4311 | ValRMSE: 19.2491
# Epoch 2/10 | Fold 5 | Train[MSE]: RMSE=18.2254 | ValRMSE: 19.2954
# Epoch 3/10 | Fold 5 | Train[MSE]: RMSE=16.1081 | ValRMSE: 19.6143
# Epoch 4/10 | Fold 5 | Train[MSE]: RMSE=13.5840 | ValRMSE: 20.0343
# Epoch 5/10 | Fold 5 | Train[MSE]: RMSE=11.6396 | ValRMSE: 20.5533
# Epoch 6/10 | Fold 5 | Train[MSE]: RMSE=10.3287 | ValRMSE: 20.2792
# Early stopping at epoch 6
# Fold 5 best RMSE: 19.2491
#
# Total training time: 8m 54s
#
# OOF RMSE: 18.8632
# Fold RMSEs: [19.177032470703125, 18.99273109436035, 18.306753158569336, 18.572696685791016, 19.24906349182129]  Mean=18.8597  Std=0.3628

# %%
import pandas
df = pd.read_csv(out_dir+"/oof_detail.csv")
fold_rmse = []

for fold in range(1, 6):
    sub = df[df.fold == fold]
    rmse = ((sub.ytrue - sub.oof_pred)**2).mean() ** 0.5
    fold_rmse.append(rmse)
    print(f"Fold {fold} OOF RMSE: {rmse:.4f} (n={len(sub)})")
# Out:
# Fold 1 OOF RMSE: 19.1770 (n=1983)
# Fold 2 OOF RMSE: 18.9927 (n=1983)
# Fold 3 OOF RMSE: 18.3068 (n=1982)
# Fold 4 OOF RMSE: 18.5727 (n=1982)
# Fold 5 OOF RMSE: 19.2491 (n=1982)

# %%
from src.plot import plot_train_val_history
plot_train_val_history(out_dir, folds=[1,2,3,4,5], title_prefix="Exp12 FiLM Layer after Feature Extraction EfficientNetB1")

# %%
from src.plot import plot_train_val_history
out_dir1 = os.path.join("../..", "outputs", "exp4")
plot_train_val_history(out_dir1, folds=[1,2,3,4,5], title_prefix="Exp4 FeatureConcatFusion EfficientNetB1")

# %%
from src.plot import plot_compare_two_experiments
plot_compare_two_experiments(out_dir, out_dir1,folds=[1,2,3,4,5], label_a="Exp12 FiLM internal Final EfficientNetB1", label_b="Exp4 FeatureConcatFusion EfficientNetB1")

# %%
from src.plot import plot_all_folds_history
plot_all_folds_history(out_dir, folds=[1,2,3,4,5], title_prefix="Exp12 FiLM Layer after Feature Extraction EfficientNetB1")

# %%
#  Inspect worst error rows

errors_path = os.path.join(out_dir, "top50_errors.csv")
err_df = pd.read_csv(errors_path)
err_df.head()
# Out:
#                                  Id  fold  ytrue   oof_pred    abs_err
# 0  76769dbee1699e04ae1befa3128db7d6     2    100  23.733664  76.266336
# 1  9f40aa2a4e04c42f3e3b6e76070f2dea     1    100  25.875875  74.124125
# 2  deb8d1618d0cdc2a78c8198b882ebb2b     3    100  26.570604  73.429396
# 3  4c1e05895368c997fdd709bbd1ac3dae     2      2  75.241356  73.241356
# 4  e2ae437b18e6ca5261acc713ecda948f     4    100  27.358297  72.641703

# %%
import os
import pandas as pd
from src.plot import (
   plot_oof_true_pred_lines,
    show_images_grid,
)

# Load OOF detail and top-errors
oof_df = pd.read_csv(os.path.join(out_dir, "oof_detail.csv"))
err_df = pd.read_csv(os.path.join(out_dir, "top50_errors.csv"))

# Plot
plot_oof_true_pred_lines(oof_df, title_prefix="Exp12")

# %%
from src.plot import compare_oof_by_bins
bins = [0, 20, 40, 60, 80, 100]

df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
    oof_path_a=os.path.join(out_dir, "oof_detail.csv"),
    oof_path_b=os.path.join(out_dir1, "oof_detail.csv"),
    bins=bins,
    label_a="Exp12_FiLM_Eff_B1 External layer FiLM Fusion",
    label_b="Exp4_FeatureConcat EffB1 Fusion",
    title_prefix="EfficientNet",
)
# Out:
# Exp12_FiLM_Eff_B1 External layer FiLM Fusion OOF RMSE: 18.86318997369515
# Exp4_FeatureConcat EffB1 Fusion OOF RMSE: 19.90331621767278
# ΔRMSE (Exp4_FeatureConcat EffB1 Fusion - Exp12_FiLM_Eff_B1 External layer FiLM Fusion): 1.0401262439776318

# %%
df_bins.head()
# Out:
#          bin  count  Exp12_FiLM_Eff_B1 External layer FiLM Fusion_rmse  \
# 0    (0, 20]   1417                                          24.861706
# 1   (20, 40]   5119                                          10.515809
# 2   (40, 60]   2088                                          13.411293
# 3   (60, 80]    727                                          27.181583
# 4  (80, 100]    561                                          45.712302
#
#    Exp4_FeatureConcat EffB1 Fusion_rmse  rmse_diff  \
# 0                             23.561754  -1.299952
# 1                             11.605182   1.089372
# 2                             16.538259   3.126967
# 3                             30.127592   2.946010
# 4                             46.623998   0.911697
#
#                                               winner
# 0             Exp4_FeatureConcat EffB1 Fusion_better
# 1  Exp12_FiLM_Eff_B1 External layer FiLM Fusion_b...
# 2  Exp12_FiLM_Eff_B1 External layer FiLM Fusion_b...
# 3  Exp12_FiLM_Eff_B1 External layer FiLM Fusion_b...
# 4  Exp12_FiLM_Eff_B1 External layer FiLM Fusion_b...
