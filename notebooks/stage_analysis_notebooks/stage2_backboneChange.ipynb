# %% [markdown]
# ### In this stage, the backbone based on cnn and tranformer based are compared

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.insert(0, os.path.abspath("../.."))

# %% [markdown]
# ### 1. EfficientB0_256_LiteAug vs SWIN_384_StrongAug

# %%
from src.plot import compare_oof_by_bins
bins = [0, 20, 40, 60, 80, 100]

df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
    oof_path_a="../../outputs/exp2/oof_detail.csv",
    oof_path_b="../../outputs/exp3/oof_detail.csv",
    bins=bins,
    label_a="Exp2_Eff_256_lite_NoFusion",
    label_b="Exp3_Swin_384_Strong_NoFusion",
    title_prefix="Exp2_Eff_256_lite_NoFusion vs Exp3_Swin_384_Strong_NoFusion",
)
# Out:
# Exp2_Eff_256_lite_NoFusion OOF RMSE: 19.177387932516293
# Exp3_Swin_384_Strong_NoFusion OOF RMSE: 17.714745225456582
# ΔRMSE (Exp3_Swin_384_Strong_NoFusion - Exp2_Eff_256_lite_NoFusion): -1.462642707059711

# %%
df_bins.head()
# Out:
#          bin  count  Exp2_Eff_256_lite_NoFusion_rmse  \
# 0    (0, 20]   1417                        24.106148
# 1   (20, 40]   5119                        10.851486
# 2   (40, 60]   2088                        14.386820
# 3   (60, 80]    727                        27.984539
# 4  (80, 100]    561                        46.588225
#
#    Exp3_Swin_384_Strong_NoFusion_rmse  rmse_diff  \
# 0                           24.496437   0.390289
# 1                            9.970236  -0.881250
# 2                           13.859223  -0.527597
# 3                           24.577702  -3.406837
# 4                           40.300325  -6.287900
#
#                                  winner
# 0     Exp2_Eff_256_lite_NoFusion_better
# 1  Exp3_Swin_384_Strong_NoFusion_better
# 2  Exp3_Swin_384_Strong_NoFusion_better
# 3  Exp3_Swin_384_Strong_NoFusion_better
# 4  Exp3_Swin_384_Strong_NoFusion_better

# %% [markdown]
# ### 2. EfficientB4_384_StrongAug vs SWIN_384_StrongAug

# %%
from src.plot import compare_oof_by_bins
bins = [0, 20, 40, 60, 80, 100]

df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
    oof_path_a="../../outputs/exp8/oof_detail.csv",
    oof_path_b="../../outputs/exp3/oof_detail.csv",
    bins=bins,
    label_a="EfficientB4_384_StrongAug",
    label_b="SWIN_384_Strong",
    title_prefix="EfficientB4_384_StrongAug  vs SWIN_384_Strong",
)
# Out:
# EfficientB4_384_StrongAug OOF RMSE: 18.682241951546622
# SWIN_384_Strong OOF RMSE: 17.714745225456582
# ΔRMSE (SWIN_384_Strong - EfficientB4_384_StrongAug): -0.9674967260900402

# %%
df_bins.head()
# Out:
#          bin  count  EfficientB4_384_StrongAug_rmse  SWIN_384_Strong_rmse  \
# 0    (0, 20]   1417                       22.815533             24.496437
# 1   (20, 40]   5119                        8.891782              9.970236
# 2   (40, 60]   2088                       14.525071             13.859223
# 3   (60, 80]    727                       28.761188             24.577702
# 4  (80, 100]    561                       47.678782             40.300325
#
#    rmse_diff                            winner
# 0   1.680904  EfficientB4_384_StrongAug_better
# 1   1.078454  EfficientB4_384_StrongAug_better
# 2  -0.665848            SWIN_384_Strong_better
# 3  -4.183486            SWIN_384_Strong_better
# 4  -7.378457            SWIN_384_Strong_better
