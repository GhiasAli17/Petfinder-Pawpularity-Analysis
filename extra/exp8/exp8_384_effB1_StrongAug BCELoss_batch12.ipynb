# %% [markdown]
# ### Architecture
# In this experiment, EfficientNet_B4 is applied and last layer is removed with single output for the pawpularity finetuning without metadata inclusion. strong augmentation is added

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.insert(0, os.path.abspath("../.."))

# %%
#  imports & setup
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import gc

gc.enable()

import torch


from src.config import EXP_CONFIGS
from src.utils import set_seed, save_config


main_folder = "../.."
data_csv = os.path.join(main_folder, "data", "train.csv")
img_folder = os.path.join(main_folder, "data", "train")
out_dir = os.path.join(main_folder, "outputs","extra", "exp8_384_effB1_strongAug_BCELoss_batch12")

df = pd.read_csv(data_csv)
cfg = EXP_CONFIGS["exp8"]
cfg["name"] = "exp8_384_effB1_strongAug_BCELoss_batch12"
cfg["img_size"] = 384
cfg["backbone"] = "efficientnet_b1"
cfg["aug"] = "strong"
cfg["loss"] = "bce"
cfg["batch_size"] = 12
TARGET = "Pawpularity"
tab_cols = [c for c in df.columns if c not in ["Id", TARGET]]

os.makedirs(out_dir, exist_ok=True)
save_config(cfg, out_dir)
set_seed(cfg["seed"])
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import root_mean_squared_error
from src.train import run_single_fold
import time

kf = KFold(n_splits=cfg["n_splits"], shuffle=True, random_state=cfg["seed"])
oof_pred = np.zeros(len(df))
oof_true = df[TARGET].values
fold_index = np.full(len(df), -1, dtype=int)
fold_rmse = []

# id2idx = {id_: i for i, id_ in enumerate(df["Id"].values)}
start_all = time.time()

for fold, (tr_idx, val_idx) in enumerate(kf.split(df), start=1):
    print(f"\n=== {cfg['name']}: Fold {fold} ===")
    train_df = df.iloc[tr_idx].reset_index(drop=True)
    val_df   = df.iloc[val_idx].reset_index(drop=True)

    best_rmse, val_preds, val_targets, val_ids = run_single_fold(
        fold=fold,
        train_df=train_df,
        val_df=val_df,
        img_folder=img_folder,
        cfg=cfg,
        out_dir=out_dir,
        device=device,
        mode="image",
        tab_cols=None,
        workers=16,
        pin_memory=True,
        persistent_workers=True,
    )

    oof_pred[val_idx] = val_preds
    fold_index[val_idx] = fold
    
    fold_rmse.append(best_rmse)
    print(f"Fold {fold} best RMSE: {best_rmse:.4f}")


all_sec = time.time() - start_all
print(f"\nTotal training time: {int(all_sec//60)}m {int(all_sec%60)}s")
# final metrics + OOF with fold column
oof_rmse = root_mean_squared_error(oof_true, oof_pred)
fold_rmse = np.array(fold_rmse)
print(f"\nOOF RMSE: {oof_rmse:.4f}")
print(f"Fold RMSEs: {fold_rmse.tolist()}  Mean={fold_rmse.mean():.4f}  Std={fold_rmse.std():.4f}")

oof_df = pd.DataFrame({
    "Id": df["Id"],
    "fold": fold_index,     
    "ytrue": oof_true,
    "oof_pred": oof_pred,
})
oof_df["abs_err"] = (oof_df["ytrue"] - oof_df["oof_pred"]).abs()
oof_df.to_csv(os.path.join(out_dir, "oof_detail.csv"), index=False)
oof_df.sort_values("abs_err", ascending=False).head(50).to_csv(
    os.path.join(out_dir, "top50_errors.csv"), index=False
)

np.save(os.path.join(out_dir, "oof_pred.npy"), oof_pred)
np.save(os.path.join(out_dir, "fold_rmse.npy"), fold_rmse)
with open(os.path.join(out_dir, "metrics.txt"), "w") as f:
    f.write(f"OOF_RMSE: {oof_rmse:.4f}\n")
    f.write(f"Fold_RMSE: {fold_rmse.tolist()}\nMean: {fold_rmse.mean():.4f}\nStd: {fold_rmse.std():.4f}\n")
# Out:
# === exp8_384_effB1_strongAug_BCELoss_batch12: Fold 1 ===
# Epoch 1/10 | Fold 1 | Train[BCE]: Loss=1.2071 | ValRMSE: 37.7295
# Epoch 2/10 | Fold 1 | Train[BCE]: Loss=0.8253 | ValRMSE: 34.0776
# Epoch 3/10 | Fold 1 | Train[BCE]: Loss=0.7208 | ValRMSE: 24.8446
# Epoch 4/10 | Fold 1 | Train[BCE]: Loss=0.6806 | ValRMSE: 23.1583
# Epoch 5/10 | Fold 1 | Train[BCE]: Loss=0.6659 | ValRMSE: 21.5230
# Epoch 6/10 | Fold 1 | Train[BCE]: Loss=0.6598 | ValRMSE: 21.2810
# Epoch 7/10 | Fold 1 | Train[BCE]: Loss=0.6546 | ValRMSE: 23.1706
# Epoch 8/10 | Fold 1 | Train[BCE]: Loss=0.6516 | ValRMSE: 20.8267
# Epoch 9/10 | Fold 1 | Train[BCE]: Loss=0.6500 | ValRMSE: 21.4461
# Epoch 10/10 | Fold 1 | Train[BCE]: Loss=0.6472 | ValRMSE: 20.6154
# Fold 1 best RMSE: 20.6154
#
# === exp8_384_effB1_strongAug_BCELoss_batch12: Fold 2 ===
# Epoch 1/10 | Fold 2 | Train[BCE]: Loss=1.2509 | ValRMSE: 39.0230
# Epoch 2/10 | Fold 2 | Train[BCE]: Loss=0.8122 | ValRMSE: 31.8298
# Epoch 3/10 | Fold 2 | Train[BCE]: Loss=0.7145 | ValRMSE: 31.1239
# Epoch 4/10 | Fold 2 | Train[BCE]: Loss=0.6806 | ValRMSE: 27.6512
# Epoch 5/10 | Fold 2 | Train[BCE]: Loss=0.6659 | ValRMSE: 22.2313
# Epoch 6/10 | Fold 2 | Train[BCE]: Loss=0.6588 | ValRMSE: 23.9289
# Epoch 7/10 | Fold 2 | Train[BCE]: Loss=0.6533 | ValRMSE: 21.8600
# Epoch 8/10 | Fold 2 | Train[BCE]: Loss=0.6500 | ValRMSE: 22.7463
# Epoch 9/10 | Fold 2 | Train[BCE]: Loss=0.6475 | ValRMSE: 20.5328
# Epoch 10/10 | Fold 2 | Train[BCE]: Loss=0.6439 | ValRMSE: 20.5710
# Fold 2 best RMSE: 20.5328
#
# === exp8_384_effB1_strongAug_BCELoss_batch12: Fold 3 ===
# Epoch 1/10 | Fold 3 | Train[BCE]: Loss=1.2401 | ValRMSE: 37.0788
# Epoch 2/10 | Fold 3 | Train[BCE]: Loss=0.8586 | ValRMSE: 31.4920
# Epoch 3/10 | Fold 3 | Train[BCE]: Loss=0.7394 | ValRMSE: 26.3667
# Epoch 4/10 | Fold 3 | Train[BCE]: Loss=0.6914 | ValRMSE: 24.6011
# Epoch 5/10 | Fold 3 | Train[BCE]: Loss=0.6742 | ValRMSE: 22.1669
# Epoch 6/10 | Fold 3 | Train[BCE]: Loss=0.6621 | ValRMSE: 22.0123
# Epoch 7/10 | Fold 3 | Train[BCE]: Loss=0.6564 | ValRMSE: 20.5793
# Epoch 8/10 | Fold 3 | Train[BCE]: Loss=0.6530 | ValRMSE: 20.3845
# Epoch 9/10 | Fold 3 | Train[BCE]: Loss=0.6497 | ValRMSE: 20.9900
# Epoch 10/10 | Fold 3 | Train[BCE]: Loss=0.6474 | ValRMSE: 20.9931
# Fold 3 best RMSE: 20.3845
#
# === exp8_384_effB1_strongAug_BCELoss_batch12: Fold 4 ===
# Epoch 1/10 | Fold 4 | Train[BCE]: Loss=1.2080 | ValRMSE: 37.0869
# Epoch 2/10 | Fold 4 | Train[BCE]: Loss=0.8087 | ValRMSE: 28.7954
# Epoch 3/10 | Fold 4 | Train[BCE]: Loss=0.7074 | ValRMSE: 28.1359
# Epoch 4/10 | Fold 4 | Train[BCE]: Loss=0.6760 | ValRMSE: 28.5434
# Epoch 5/10 | Fold 4 | Train[BCE]: Loss=0.6665 | ValRMSE: 22.5065
# Epoch 6/10 | Fold 4 | Train[BCE]: Loss=0.6562 | ValRMSE: 25.9468
# Epoch 7/10 | Fold 4 | Train[BCE]: Loss=0.6541 | ValRMSE: 19.9067
# Epoch 8/10 | Fold 4 | Train[BCE]: Loss=0.6503 | ValRMSE: 19.7206
# Epoch 9/10 | Fold 4 | Train[BCE]: Loss=0.6482 | ValRMSE: 19.4092
# Epoch 10/10 | Fold 4 | Train[BCE]: Loss=0.6461 | ValRMSE: 19.3793
# Fold 4 best RMSE: 19.3793
#
# === exp8_384_effB1_strongAug_BCELoss_batch12: Fold 5 ===
# Epoch 1/10 | Fold 5 | Train[BCE]: Loss=1.3851 | ValRMSE: 43.0824
# Epoch 2/10 | Fold 5 | Train[BCE]: Loss=0.8957 | ValRMSE: 34.0374
# Epoch 3/10 | Fold 5 | Train[BCE]: Loss=0.7333 | ValRMSE: 27.5992
# Epoch 4/10 | Fold 5 | Train[BCE]: Loss=0.6901 | ValRMSE: 24.3758
# Epoch 5/10 | Fold 5 | Train[BCE]: Loss=0.6712 | ValRMSE: 23.2622
# Epoch 6/10 | Fold 5 | Train[BCE]: Loss=0.6623 | ValRMSE: 22.1921
# Epoch 7/10 | Fold 5 | Train[BCE]: Loss=0.6581 | ValRMSE: 23.1323
# Epoch 8/10 | Fold 5 | Train[BCE]: Loss=0.6523 | ValRMSE: 21.6719
# Epoch 9/10 | Fold 5 | Train[BCE]: Loss=0.6485 | ValRMSE: 21.8760
# Epoch 10/10 | Fold 5 | Train[BCE]: Loss=0.6461 | ValRMSE: 21.2712
# Fold 5 best RMSE: 21.2712
#
# Total training time: 28m 23s
#
# OOF RMSE: 20.4458
# Fold RMSEs: [20.61538314819336, 20.532819747924805, 20.38454818725586, 19.379287719726562, 21.27116584777832]  Mean=20.4366  Std=0.6096

# %%
import pandas
df = pd.read_csv(out_dir+"/oof_detail.csv")
fold_rmse = []

for fold in range(1, 6):
    sub = df[df.fold == fold]
    rmse = ((sub.ytrue - sub.oof_pred)**2).mean() ** 0.5
    fold_rmse.append(rmse)
    print(f"Fold {fold} OOF RMSE: {rmse:.4f} (n={len(sub)})")
# Out:
# Fold 1 OOF RMSE: 20.6154 (n=1983)
# Fold 2 OOF RMSE: 20.5328 (n=1983)
# Fold 3 OOF RMSE: 20.3845 (n=1982)
# Fold 4 OOF RMSE: 19.3793 (n=1982)
# Fold 5 OOF RMSE: 21.2712 (n=1982)

# %%
from src.plot import plot_all_folds_history
plot_all_folds_history(out_dir, folds=[1,2,3,4,5], title_prefix="Exp8")

# %%
# Worst error images 
errors_path = os.path.join(out_dir, "top50_errors.csv")
err_df = pd.read_csv(errors_path)
err_df.head()
# Out:
#                                  Id  fold  ytrue   oof_pred    abs_err
# 0  4c1e05895368c997fdd709bbd1ac3dae     2      2  89.825401  87.825401
# 1  ecc0e9507d22fc6563d6eaaebd166f10     5    100  13.797669  86.202331
# 2  d00e5d29d4ec09de1e0e0ebec41b2d03     1      5  89.641083  84.641083
# 3  ef7f96e35710c26e81f67ed29e967193     5    100  17.431658  82.568342
# 4  013f86ed0e765b189990d3d5ac28bd7d     1    100  18.969118  81.030882

# %%
import os
import pandas as pd
from src.plot import (
   plot_oof_true_pred_lines,
    show_images_grid,
)

# Load OOF detail and top-errors
oof_df = pd.read_csv(os.path.join(out_dir, "oof_detail.csv"))
err_df = pd.read_csv(os.path.join(out_dir, "top50_errors.csv"))

# Plots
plot_oof_true_pred_lines(oof_df, title_prefix="Exp8_256_EffB4_strongAug")

# %%
# Images of worst errors
img_folder = os.path.join(main_folder, "data", "train")
show_images_grid(err_df, img_folder, n=12, title_prefix="Exp8_256_EffB4_strongAug errors")

# %%
show_images_grid(oof_df, img_folder, n=12, title_prefix="Exp8_256_EffB4_strongAug 12 images")
