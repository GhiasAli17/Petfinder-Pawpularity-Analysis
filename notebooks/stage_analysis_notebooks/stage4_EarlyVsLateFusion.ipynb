# %% [markdown]
# > In this stage, Early fusion(SWIN+metadata MLP) and late fusion (SWIN+ GBDT_late) have very slight difference. This shows that the fusion method does not help much, since the metadata has little useful information and has no correlation with the target.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.insert(0, os.path.abspath("../.."))

# %% [markdown]
# ### 1. SWIN_384_StrongAug_earlyFusion vs SWIN_384_StrongAug_LateFusion

# %%
from src.plot import compare_oof_by_bins
bins = [0, 20, 40, 60, 80, 100]

df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
    oof_path_a="../../outputs/exp5/oof_detail.csv",
    oof_path_b="../../outputs/exp7/oof_detail.csv",
    bins=bins,
    label_a="Exp5_Swin_384_Strong_EarlyFusion",
    label_b="Exp7_Swin_384_Strong_LateFusion",
    title_prefix="Exp5_Swin_384_Strong_EarlyFusion vs Exp7_Swin_384_Strong_LateFusion",
)
# Out:
# Exp5_Swin_384_Strong_EarlyFusion OOF RMSE: 17.60001884040648
# Exp7_Swin_384_Strong_LateFusion OOF RMSE: 17.642179013734502
# ΔRMSE (Exp7_Swin_384_Strong_LateFusion - Exp5_Swin_384_Strong_EarlyFusion): 0.042160173328021244

# %%
df_bins.head()
# Out:
#          bin  count  Exp5_Swin_384_Strong_EarlyFusion_rmse  \
# 0    (0, 20]   1417                              24.173492
# 1   (20, 40]   5119                               9.572831
# 2   (40, 60]   2088                              13.258303
# 3   (60, 80]    727                              24.983769
# 4  (80, 100]    561                              41.202795
#
#    Exp7_Swin_384_Strong_LateFusion_rmse  rmse_diff  \
# 0                             24.285150   0.111658
# 1                              9.377249  -0.195581
# 2                             13.050999  -0.207305
# 3                             24.946114  -0.037655
# 4                             42.033445   0.830651
#
#                                     winner
# 0  Exp5_Swin_384_Strong_EarlyFusion_better
# 1   Exp7_Swin_384_Strong_LateFusion_better
# 2   Exp7_Swin_384_Strong_LateFusion_better
# 3   Exp7_Swin_384_Strong_LateFusion_better
# 4  Exp5_Swin_384_Strong_EarlyFusion_better
