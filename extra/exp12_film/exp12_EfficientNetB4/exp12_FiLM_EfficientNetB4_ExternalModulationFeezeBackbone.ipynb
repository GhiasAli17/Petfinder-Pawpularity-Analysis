# %% [markdown]
# ## Architecture
# In this architecuter, first feature are extracted through the Frozen EfficieneNetB4 and then additional 4 FiLMed block added where each block consist of convolutional layer, Batch Norm layer, activation (Relu), and inside each block FiLM layer is applied on feature maps/channels. rather it is additional layer on the top of extracted features from the finetuned backbone.
#
# ![image.png](attachment:image.png)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
sys.path.insert(0, os.path.abspath("../../.."))

# %%
# Cell 1: imports & setup
import os, time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gc

gc.enable()

import torch
from torch.utils.data import DataLoader
from sklearn.model_selection import KFold
from sklearn.metrics import root_mean_squared_error

from src.config import EXP_CONFIGS
from src.utils import set_seed, save_config
from src.data import build_transforms, ImageTabDataset
from src.models import FeatureConcatFusionNet, build_vision_backbone
from src.film import FiLMExternalModulation



main_folder = "../../.."
data_csv = os.path.join(main_folder, "data", "train.csv")
img_folder = os.path.join(main_folder, "data", "train")
out_dir = os.path.join(main_folder, "outputs","extra", "exp12_film_fusion_EfficientNetB4_ExternalModulation_FreezeBackbone")   # 

df = pd.read_csv(data_csv)
cfg = EXP_CONFIGS["exp12_film"]   # define in config
cfg["name"] = "exp12_film_fusion_ExternalModulation_FreezeBackbone_EffB4"
cfg["backbone"] = "efficientnet_b4"
cfg["img_size"] = 384
cfg["aug"] = "strong"

TARGET = "Pawpularity"
tab_cols = [c for c in df.columns if c not in ["Id", TARGET]]

os.makedirs(out_dir, exist_ok=True)
save_config(cfg, out_dir)
set_seed(cfg["seed"])
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import root_mean_squared_error
from src.train import run_single_fold

kf = KFold(n_splits=cfg["n_splits"], shuffle=True, random_state=cfg["seed"])
oof_pred = np.zeros(len(df))
oof_true = df[TARGET].values
fold_index = np.full(len(df), -1, dtype=int)
fold_rmse = []

start_all = time.time()
for fold, (tr_idx, val_idx) in enumerate(kf.split(df), start=1):
    print(f"\n=== {cfg['name']}: Fold {fold} ===")
    train_df = df.iloc[tr_idx].reset_index(drop=True)
    val_df   = df.iloc[val_idx].reset_index(drop=True)

    best_rmse, val_preds, val_targets, val_ids = run_single_fold(
    fold=fold,
    train_df=train_df,
    val_df=val_df,
    img_folder=img_folder,
    cfg=cfg,
    out_dir=out_dir,
    device=device,
    mode="film_stack_EffB4",   # <--- use FiLMExternalModulation    branch
    tab_cols=tab_cols,
    workers=16,
    pin_memory=True,
    persistent_workers=True,
    freeze_backbone=True,
)

    oof_pred[val_idx] = val_preds
    fold_index[val_idx] = fold
    fold_rmse.append(best_rmse)
    print(f"Fold {fold} best RMSE: {best_rmse:.4f}")

all_sec = time.time() - start_all
print(f"\nTotal training time: {int(all_sec//60)}m {int(all_sec%60)}s")
# final metrics + OOF with fold column
oof_rmse = root_mean_squared_error(oof_true, oof_pred)
fold_rmse = np.array(fold_rmse)
print(f"\nOOF RMSE: {oof_rmse:.4f}")
print(f"Fold RMSEs: {fold_rmse.tolist()}  Mean={fold_rmse.mean():.4f}  Std={fold_rmse.std():.4f}")

oof_df = pd.DataFrame({
    "Id": df["Id"],
    "fold": fold_index,     
    "ytrue": oof_true,
    "oof_pred": oof_pred,
})
oof_df["abs_err"] = (oof_df["ytrue"] - oof_df["oof_pred"]).abs()
oof_df.to_csv(os.path.join(out_dir, "oof_detail.csv"), index=False)
oof_df.sort_values("abs_err", ascending=False).head(50).to_csv(
    os.path.join(out_dir, "top50_errors.csv"), index=False
)

np.save(os.path.join(out_dir, "oof_pred.npy"), oof_pred)
np.save(os.path.join(out_dir, "fold_rmse.npy"), fold_rmse)
with open(os.path.join(out_dir, "metrics.txt"), "w") as f:
    f.write(f"OOF_RMSE: {oof_rmse:.4f}\n")
    f.write(f"Fold_RMSE: {fold_rmse.tolist()}\nMean: {fold_rmse.mean():.4f}\nStd: {fold_rmse.std():.4f}\n")
# Out:
# === exp12_film_fusion_ExternalModulation_FreezeBackbone_EffB4: Fold 1 ===
# Epoch 1/10 | Fold 1 | Train[MSE]: RMSE=42.5997 | ValRMSE: 42.0371
# Epoch 2/10 | Fold 1 | Train[MSE]: RMSE=40.7497 | ValRMSE: 39.6858
# Epoch 3/10 | Fold 1 | Train[MSE]: RMSE=37.9211 | ValRMSE: 36.3316
# Epoch 4/10 | Fold 1 | Train[MSE]: RMSE=34.3924 | ValRMSE: 32.5740
# Epoch 5/10 | Fold 1 | Train[MSE]: RMSE=30.8067 | ValRMSE: 29.4369
# Epoch 6/10 | Fold 1 | Train[MSE]: RMSE=28.1196 | ValRMSE: 27.2702
# Epoch 7/10 | Fold 1 | Train[MSE]: RMSE=26.2188 | ValRMSE: 25.7255
# Epoch 8/10 | Fold 1 | Train[MSE]: RMSE=25.1270 | ValRMSE: 25.0731
# Epoch 9/10 | Fold 1 | Train[MSE]: RMSE=24.6170 | ValRMSE: 24.9522
# Epoch 10/10 | Fold 1 | Train[MSE]: RMSE=24.3207 | ValRMSE: 24.6480
# Fold 1 best RMSE: 24.6480
#
# === exp12_film_fusion_ExternalModulation_FreezeBackbone_EffB4: Fold 2 ===
# Epoch 1/10 | Fold 2 | Train[MSE]: RMSE=42.6436 | ValRMSE: 41.9661
# Epoch 2/10 | Fold 2 | Train[MSE]: RMSE=40.8410 | ValRMSE: 39.6129
# Epoch 3/10 | Fold 2 | Train[MSE]: RMSE=38.1534 | ValRMSE: 36.4386
# Epoch 4/10 | Fold 2 | Train[MSE]: RMSE=34.7305 | ValRMSE: 32.7364
# Epoch 5/10 | Fold 2 | Train[MSE]: RMSE=31.2567 | ValRMSE: 29.4625
# Epoch 6/10 | Fold 2 | Train[MSE]: RMSE=28.4481 | ValRMSE: 27.0443
# Epoch 7/10 | Fold 2 | Train[MSE]: RMSE=26.5308 | ValRMSE: 25.6679
# Epoch 8/10 | Fold 2 | Train[MSE]: RMSE=25.4487 | ValRMSE: 24.7581
# Epoch 9/10 | Fold 2 | Train[MSE]: RMSE=24.8053 | ValRMSE: 24.4136
# Epoch 10/10 | Fold 2 | Train[MSE]: RMSE=24.6694 | ValRMSE: 24.4998
# Fold 2 best RMSE: 24.4136
#
# === exp12_film_fusion_ExternalModulation_FreezeBackbone_EffB4: Fold 3 ===
# Epoch 1/10 | Fold 3 | Train[MSE]: RMSE=42.7283 | ValRMSE: 41.1440
# Epoch 2/10 | Fold 3 | Train[MSE]: RMSE=40.5715 | ValRMSE: 38.4066
# Epoch 3/10 | Fold 3 | Train[MSE]: RMSE=37.2636 | ValRMSE: 34.4498
# Epoch 4/10 | Fold 3 | Train[MSE]: RMSE=33.2542 | ValRMSE: 30.1821
# Epoch 5/10 | Fold 3 | Train[MSE]: RMSE=29.3836 | ValRMSE: 26.5931
# Epoch 6/10 | Fold 3 | Train[MSE]: RMSE=26.4447 | ValRMSE: 24.3798
# Epoch 7/10 | Fold 3 | Train[MSE]: RMSE=24.6420 | ValRMSE: 23.1386
# Epoch 8/10 | Fold 3 | Train[MSE]: RMSE=23.6716 | ValRMSE: 22.5776
# Epoch 9/10 | Fold 3 | Train[MSE]: RMSE=23.1370 | ValRMSE: 22.1395
# Epoch 10/10 | Fold 3 | Train[MSE]: RMSE=23.0328 | ValRMSE: 22.2376
# Fold 3 best RMSE: 22.1395
#
# === exp12_film_fusion_ExternalModulation_FreezeBackbone_EffB4: Fold 4 ===
# Epoch 1/10 | Fold 4 | Train[MSE]: RMSE=42.7734 | ValRMSE: 41.7227
# Epoch 2/10 | Fold 4 | Train[MSE]: RMSE=41.0292 | ValRMSE: 39.4715
# Epoch 3/10 | Fold 4 | Train[MSE]: RMSE=38.3866 | ValRMSE: 36.4821
# Epoch 4/10 | Fold 4 | Train[MSE]: RMSE=34.8906 | ValRMSE: 32.6130
# Epoch 5/10 | Fold 4 | Train[MSE]: RMSE=31.3733 | ValRMSE: 29.2307
# Epoch 6/10 | Fold 4 | Train[MSE]: RMSE=28.4525 | ValRMSE: 26.8109
# Epoch 7/10 | Fold 4 | Train[MSE]: RMSE=26.5400 | ValRMSE: 25.5190
# Epoch 8/10 | Fold 4 | Train[MSE]: RMSE=25.4044 | ValRMSE: 24.5134
# Epoch 9/10 | Fold 4 | Train[MSE]: RMSE=24.6754 | ValRMSE: 24.1696
# Epoch 10/10 | Fold 4 | Train[MSE]: RMSE=24.4682 | ValRMSE: 24.0569
# Fold 4 best RMSE: 24.0569
#
# === exp12_film_fusion_ExternalModulation_FreezeBackbone_EffB4: Fold 5 ===
# Epoch 1/10 | Fold 5 | Train[MSE]: RMSE=42.5472 | ValRMSE: 42.2316
# Epoch 2/10 | Fold 5 | Train[MSE]: RMSE=40.6770 | ValRMSE: 39.8064
# Epoch 3/10 | Fold 5 | Train[MSE]: RMSE=37.7792 | ValRMSE: 36.2522
# Epoch 4/10 | Fold 5 | Train[MSE]: RMSE=34.1582 | ValRMSE: 32.4399
# Epoch 5/10 | Fold 5 | Train[MSE]: RMSE=30.3841 | ValRMSE: 28.7873
# Epoch 6/10 | Fold 5 | Train[MSE]: RMSE=27.5279 | ValRMSE: 26.3850
# Epoch 7/10 | Fold 5 | Train[MSE]: RMSE=25.5097 | ValRMSE: 25.0514
# Epoch 8/10 | Fold 5 | Train[MSE]: RMSE=24.3892 | ValRMSE: 24.3883
# Epoch 9/10 | Fold 5 | Train[MSE]: RMSE=23.8289 | ValRMSE: 23.8569
# Epoch 10/10 | Fold 5 | Train[MSE]: RMSE=23.6446 | ValRMSE: 23.8333
# Fold 5 best RMSE: 23.8333
#
# Total training time: 16m 20s
#
# OOF RMSE: 23.8348
# Fold RMSEs: [24.648042678833008, 24.413606643676758, 22.13945198059082, 24.056921005249023, 23.833271026611328]  Mean=23.8183  Std=0.8853

# %%
#oof rmse = 23.8348
import pandas
df = pd.read_csv(out_dir+"/oof_detail.csv")
fold_rmse = []

for fold in range(1, 6):
    sub = df[df.fold == fold]
    rmse = ((sub.ytrue - sub.oof_pred)**2).mean() ** 0.5
    fold_rmse.append(rmse)
    print(f"Fold {fold} OOF RMSE: {rmse:.4f} (n={len(sub)})")
# Out:
# Fold 1 OOF RMSE: 24.6480 (n=1983)
# Fold 2 OOF RMSE: 24.4136 (n=1983)
# Fold 3 OOF RMSE: 22.1395 (n=1982)
# Fold 4 OOF RMSE: 24.0569 (n=1982)
# Fold 5 OOF RMSE: 23.8333 (n=1982)

# %%
from src.plot import plot_train_val_history
plot_train_val_history(out_dir, folds=[1,2,3,4,5], title_prefix="Exp12 FiLM Layer after Freeze BackboneFeature Extraction EfficientNetB4")

# %%
from src.plot import plot_train_val_history
out_dir1 = os.path.join("../../..", "outputs", "exp4")
plot_train_val_history(out_dir1, folds=[1,2,3,4,5], title_prefix="Exp4 FeatureConcatFusion EfficientNetB4")

# %%
from src.plot import plot_compare_two_experiments
plot_compare_two_experiments(out_dir, out_dir1,folds=[1,2,3,4,5], label_a="Exp12 FiLM Layer after Freeze BackboneFeature Extraction EfficientNetB4", label_b="Exp4 FeatureConcatFusion EfficientNetB4")

# %%
from src.plot import plot_all_folds_history
plot_all_folds_history(out_dir, folds=[1,2,3,4,5], title_prefix="Exp12 FiLM EfficientNetB4")

# %%
#  Inspect worst error rows

errors_path = os.path.join(out_dir, "top50_errors.csv")
err_df = pd.read_csv(errors_path)
err_df.head()
# Out:
#                                  Id  fold  ytrue   oof_pred    abs_err
# 0  6dcb7396e06ee6a538522d2f67f017db     5    100  11.944178  88.055822
# 1  83fe342b3d1f365f8b62272319890cf9     2    100  14.481450  85.518550
# 2  2114efb5473197ce31bcc75018c71660     1    100  16.885546  83.114454
# 3  013f86ed0e765b189990d3d5ac28bd7d     1    100  18.098454  81.901546
# 4  c9ab9ed4f8bbdb9efa80330652a7b04a     1    100  19.890200  80.109800

# %%
import os
import pandas as pd
from src.plot import (
   plot_oof_true_pred_lines,
    show_images_grid,
)

# Load OOF detail and top-errors
oof_df = pd.read_csv(os.path.join(out_dir, "oof_detail.csv"))
err_df = pd.read_csv(os.path.join(out_dir, "top50_errors.csv"))

# Plot
plot_oof_true_pred_lines(oof_df, title_prefix="Exp12")

# %%
from src.plot import compare_oof_by_bins
bins = [0, 20, 40, 60, 80, 100]

df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
    oof_path_a=os.path.join(out_dir, "oof_detail.csv"),
    oof_path_b=os.path.join(out_dir1, "oof_detail.csv"),
    bins=bins,
    label_a="Exp12_FiLM_Eff_B4 Frozen image backbone and  External layer FiLM Fusion",
    label_b="Exp4_FeatureConcat EffB4 Fusion",
    title_prefix="EfficientNet",
)
# Out:
# Exp12_FiLM_Eff_B4 Frozen image backbone and  External layer FiLM Fusion OOF RMSE: 23.83484790514939
# Exp4_FeatureConcat EffB4 Fusion OOF RMSE: 19.90331621767278
# ΔRMSE (Exp4_FeatureConcat EffB4 Fusion - Exp12_FiLM_Eff_B4 Frozen image backbone and  External layer FiLM Fusion): -3.931531687476607

# %%
df_bins.head()
# Out:
#          bin  count  \
# 0    (0, 20]   1417
# 1   (20, 40]   5119
# 2   (40, 60]   2088
# 3   (60, 80]    727
# 4  (80, 100]    561
#
#    Exp12_FiLM_Eff_B4 Frozen image backbone and  External layer FiLM Fusion_rmse  \
# 0                                          15.397515
# 1                                           7.523138
# 2                                          22.741243
# 3                                          42.652109
# 4                                          68.116207
#
#    Exp4_FeatureConcat EffB4 Fusion_rmse  rmse_diff  \
# 0                             23.561754   8.164238
# 1                             11.605182   4.082044
# 2                             16.538259  -6.202983
# 3                             30.127592 -12.524517
# 4                             46.623998 -21.492209
#
#                                               winner
# 0  Exp12_FiLM_Eff_B4 Frozen image backbone and  E...
# 1  Exp12_FiLM_Eff_B4 Frozen image backbone and  E...
# 2             Exp4_FeatureConcat EffB4 Fusion_better
# 3             Exp4_FeatureConcat EffB4 Fusion_better
# 4             Exp4_FeatureConcat EffB4 Fusion_better
