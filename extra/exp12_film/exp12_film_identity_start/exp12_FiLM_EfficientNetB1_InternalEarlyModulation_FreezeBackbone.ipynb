# Epoch 7/10 | Fold 5 | Train[MSE]: RMSE=25.2593 | ValRMSE: 26.9068
# Epoch 8/10 | Fold 5 | Train[MSE]: RMSE=25.0559 | ValRMSE: 27.0139
# Epoch 9/10 | Fold 5 | Train[MSE]: RMSE=24.9255 | ValRMSE: 26.6816
# Epoch 10/10 | Fold 5 | Train[MSE]: RMSE=24.9342 | ValRMSE: 26.8453
# Fold 5 best RMSE: 26.6816
#
# Total training time: 10m 3s
#
# OOF RMSE: 26.3029
# Fold RMSEs: [27.143400192260742, 26.323259353637695, 25.457340240478516, 25.87522315979004, 26.681589126586914]  Mean=26.2962  Std=0.5913

# %%
import pandas as pd
df = pd.read_csv(out_dir+"/oof_detail.csv")
fold_rmse = []

for fold in range(1, 6):
    sub = df[df.fold == fold]
    rmse = ((sub.ytrue - sub.oof_pred)**2).mean() ** 0.5
    fold_rmse.append(rmse)
    print(f"Fold {fold} OOF RMSE: {rmse:.4f} (n={len(sub)})")
# Out:
# Fold 1 OOF RMSE: 27.1434 (n=1983)
# Fold 2 OOF RMSE: 26.3233 (n=1983)
# Fold 3 OOF RMSE: 25.4573 (n=1982)
# Fold 4 OOF RMSE: 25.8752 (n=1982)
# Fold 5 OOF RMSE: 26.6816 (n=1982)

# %% [markdown]
# ### Train and Validation RMSE Curve

# %%
from src.plot import plot_train_val_history
plot_train_val_history(out_dir, folds=[1,2,3,4,5], title_prefix="Exp12 FiLM Block1 Early Modulation FreezeEfficientNetB1")

# %%
from src.plot import plot_train_val_history
out_dir1 = os.path.join("../..", "outputs", "exp4")
plot_train_val_history(out_dir1, folds=[1,2,3,4,5], title_prefix="Exp4 FeatureConcatFusion EfficientNetB1")

# %% [markdown]
# ### Side by Side Comparison with Concatenation based Feature Fusion Exp4

# %%
from src.plot import plot_compare_two_experiments
plot_compare_two_experiments(out_dir, out_dir1,folds=[1,2,3,4,5], label_a="Exp12 FiLM Block1 Early Modulation FreezeEfficientNetB1", label_b="Exp4 FeatureConcatFusion EfficientNetB1")

# %%
#  Inspect worst error rows

errors_path = os.path.join(out_dir, "top50_errors.csv")
err_df = pd.read_csv(errors_path)
err_df.head()
# Out:
#                                  Id  fold  ytrue  oof_pred     abs_err
# 0  587c58bb1bc45cd903c18a3554b83c72     5    100 -0.645287  100.645287
# 1  d221b46947fc086e7445590e2bd1e808     4    100 -0.460205  100.460205
# 2  99b0131884ce44bec548e586412c0d07     4    100 -0.431846  100.431846
# 3  869326d56a88de6e4983d90883c0e09c     4    100 -0.322591  100.322591
# 4  fe200aff478f55ca4bcf77d9dade1217     5    100 -0.148564  100.148564

# %%
import os
import pandas as pd
from src.plot import (
   plot_oof_true_pred_lines,
    show_images_grid,
)

# Load OOF detail and top-errors
oof_df = pd.read_csv(os.path.join(out_dir, "oof_detail.csv"))
err_df = pd.read_csv(os.path.join(out_dir, "top50_errors.csv"))

# Plot
plot_oof_true_pred_lines(oof_df, title_prefix="Exp12 FiLM Block1 Early Modulation FreezeEfficientNetB1")

# %%
from src.plot import compare_oof_by_bins
bins = [0, 20, 40, 60, 80, 100]

df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
    oof_path_a=os.path.join(out_dir, "oof_detail.csv"),
    oof_path_b=os.path.join(out_dir1, "oof_detail.csv"),
    bins=bins,
    label_a="Exp12 FiLM Block1 Early Modulation FreezeEfficientNetB1",
    label_b="Exp4_FeatureConcat EffB1 Fusion",
    title_prefix="EfficientNet",
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 from src.plot import compare_oof_by_bins
#       2 bins = [0, 20, 40, 60, 80, 100]
# ----> 4 df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
#       5     oof_path_a=os.path.join(out_dir, "oof_detail.csv"),
#       6     oof_path_b=os.path.join(out_dir1, "oof_detail.csv"),
#       7     bins=bins,
#       8     label_a="Exp12 FiLM Block1 Early Modulation FreezeEfficientNetB1",
#       9     label_b="Exp4_FeatureConcat EffB1 Fusion",
#      10     title_prefix="EfficientNet",
#      11 )
#
# File ~/Petfinder-Pawpularity-Modular/src/plot.py:386, in compare_oof_by_bins(oof_path_a, oof_path_b, bins, label_a, label_b, title_prefix)
#     384 # --- load and bin ---
#     385 oof_a = pd.read_csv(oof_path_a)
# --> 386 oof_b = pd.read_csv(oof_path_b)
#     388 oof_a["bin"] = pd.cut(oof_a["ytrue"], bins)
#     389 oof_b["bin"] = pd.cut(oof_b["ytrue"], bins)
#
# File ~/miniconda3/envs/rapids-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/rapids-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniconda3/envs/rapids-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/rapids-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/miniconda3/envs/rapids-env/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../outputs/exp4/oof_detail.csv'

# %%
df_bins.head()
# Out:
#          bin  count  \
# 0    (0, 20]   1417
# 1   (20, 40]   5119
# 2   (40, 60]   2088
# 3   (60, 80]    727
# 4  (80, 100]    561
#
#    Exp12 FiLM Block1 Early Modulation FreezeEfficientNetB1_rmse  \
# 0                                          18.191473
# 1                                          15.957983
# 2                                          29.015770
# 3                                          47.253932
# 4                                          72.650126
#
#    Exp4_FeatureConcat EffB1 Fusion_rmse  rmse_diff  \
# 0                             23.561754   5.370281
# 1                             11.605182  -4.352801
# 2                             16.538259 -12.477511
# 3                             30.127592 -17.126340
# 4                             46.623998 -26.026128
#
#                                               winner
# 0  Exp12 FiLM Block1 Early Modulation FreezeEffic...
# 1             Exp4_FeatureConcat EffB1 Fusion_better
# 2             Exp4_FeatureConcat EffB1 Fusion_better
# 3             Exp4_FeatureConcat EffB1 Fusion_better
# 4             Exp4_FeatureConcat EffB1 Fusion_better

# %%
# Images of worst errors of FiLM 12 experiment
img_folder = os.path.join(main_folder, "data", "train")
show_images_grid(err_df, img_folder, n=12, title_prefix="Exp12 FiLM Block1 Early Modulation FreezeEfficientNetB1")

# %%
# Load OOF detail and top-errors of Exp4 
oof_df1 = pd.read_csv(os.path.join(out_dir1, "oof_detail.csv"))
err_df1 = pd.read_csv(os.path.join(out_dir1, "top50_errors.csv"))
show_images_grid(err_df1, img_folder, n=12, title_prefix="exp4_featurebased concat fusion 12 images")
