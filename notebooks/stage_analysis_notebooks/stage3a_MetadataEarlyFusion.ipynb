# %% [markdown]
# ### In this stage, the metadata is included via early fusion

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.insert(0, os.path.abspath("../.."))

# %% [markdown]
# ### 1. SWIN only vs SWIN + Metadata Early Fusion

# %%
from src.plot import compare_oof_by_bins
bins = [0, 20, 40, 60, 80, 100]

df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
    oof_path_a="../../outputs/exp3/oof_detail.csv",
    oof_path_b="../../outputs/exp5/oof_detail.csv",
    bins=bins,
    label_a="Exp3_Swin_NoFusion",
    label_b="Exp5_Swin_EarlyFusion",
    title_prefix="Swin",
)
# Out:
# Exp3_Swin_NoFusion OOF RMSE: 17.714745225456582
# Exp5_Swin_EarlyFusion OOF RMSE: 17.60001884040648
# ΔRMSE (Exp5_Swin_EarlyFusion - Exp3_Swin_NoFusion): -0.11472638505010124

# %%
df_bins.head()
# Out:
#          bin  count  Exp3_Swin_NoFusion_rmse  Exp5_Swin_EarlyFusion_rmse  \
# 0    (0, 20]   1417                24.496437                   24.173492
# 1   (20, 40]   5119                 9.970236                    9.572831
# 2   (40, 60]   2088                13.859223                   13.258303
# 3   (60, 80]    727                24.577702                   24.983769
# 4  (80, 100]    561                40.300325                   41.202795
#
#    rmse_diff                        winner
# 0  -0.322945  Exp5_Swin_EarlyFusion_better
# 1  -0.397406  Exp5_Swin_EarlyFusion_better
# 2  -0.600919  Exp5_Swin_EarlyFusion_better
# 3   0.406067     Exp3_Swin_NoFusion_better
# 4   0.902470     Exp3_Swin_NoFusion_better

# %% [markdown]
# ### 2. EfficientEarlyFusion vs Efficient Image Only

# %%
df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
    oof_path_a="../../outputs/exp4/oof_detail.csv",
    oof_path_b="../../outputs/extra/exp2_256_effB1/oof_detail.csv",
    bins=bins,
    label_a="Exp4_EfficientB1_256_Lite_Metadata_EarlyFusion",
    label_b="exp2_EfficientB1_256_Lite_noFusion",
    title_prefix="Swin",
)
# Out:
# Exp4_EfficientB1_256_Lite_Metadata_EarlyFusion OOF RMSE: 19.90331621767278
# exp2_EfficientB1_256_Lite_noFusion OOF RMSE: 19.6039434522729
# ΔRMSE (exp2_EfficientB1_256_Lite_noFusion - Exp4_EfficientB1_256_Lite_Metadata_EarlyFusion): -0.29937276539988034

# %%
df_bins.head()
# Out:
#          bin  count  Exp4_EfficientB1_256_Lite_Metadata_EarlyFusion_rmse  \
# 0    (0, 20]   1417                                          23.561754
# 1   (20, 40]   5119                                          11.605182
# 2   (40, 60]   2088                                          16.538259
# 3   (60, 80]    727                                          30.127592
# 4  (80, 100]    561                                          46.623998
#
#    exp2_EfficientB1_256_Lite_noFusion_rmse  rmse_diff  \
# 0                                25.551645   1.989891
# 1                                11.645200   0.040018
# 2                                14.360283  -2.177976
# 3                                27.422595  -2.704998
# 4                                46.494001  -0.129997
#
#                                               winner
# 0  Exp4_EfficientB1_256_Lite_Metadata_EarlyFusion...
# 1  Exp4_EfficientB1_256_Lite_Metadata_EarlyFusion...
# 2          exp2_EfficientB1_256_Lite_noFusion_better
# 3          exp2_EfficientB1_256_Lite_noFusion_better
# 4          exp2_EfficientB1_256_Lite_noFusion_better
