# %% [markdown]
# ### In this stage, the metadata is included by late fusion, so image only model and image with metadata late are compared

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.insert(0, os.path.abspath("../.."))

# %% [markdown]
# ### 1. SWIN only vs SWIN + Metadata Late Fusion

# %%
from src.plot import compare_oof_by_bins
bins = [0, 20, 40, 60, 80, 100]

df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
    oof_path_a="../../outputs/exp3/oof_detail.csv",
    oof_path_b="../../outputs/exp7/oof_detail.csv",
    bins=bins,
    label_a="Exp3_Swin_NoFusion",
    label_b="Exp7_Swin_LateFusion",
    title_prefix="Exp3_Swin_NoFusion VS Exp7_Swin_LateFusion",
)
# Out:
# Exp3_Swin_NoFusion OOF RMSE: 17.714745225456582
# Exp7_Swin_LateFusion OOF RMSE: 17.642179013734502
# ΔRMSE (Exp7_Swin_LateFusion - Exp3_Swin_NoFusion): -0.07256621172208

# %%
df_bins.head()
# Out:
#          bin  count  Exp3_Swin_NoFusion_rmse  Exp7_Swin_LateFusion_rmse  \
# 0    (0, 20]   1417                24.496437                  24.285150
# 1   (20, 40]   5119                 9.970236                   9.377249
# 2   (40, 60]   2088                13.859223                  13.050999
# 3   (60, 80]    727                24.577702                  24.946114
# 4  (80, 100]    561                40.300325                  42.033445
#
#    rmse_diff                       winner
# 0  -0.211287  Exp7_Swin_LateFusion_better
# 1  -0.592987  Exp7_Swin_LateFusion_better
# 2  -0.808224  Exp7_Swin_LateFusion_better
# 3   0.368412    Exp3_Swin_NoFusion_better
# 4   1.733121    Exp3_Swin_NoFusion_better
