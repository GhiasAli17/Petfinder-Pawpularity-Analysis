# %% [markdown]
# ## Architecture
# In this architecuter, first feature are extracted through the Frozen EfficieneNetB4 and then additional 4 FiLMed block added where each block consist of convolutional layer, Batch Norm layer, activation (Relu), and inside each block FiLM layer is applied on feature maps/channels. rather it is additional layer on the top of extracted features from the finetuned backbone.
#
# ![image.png](attachment:image.png)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.insert(0, os.path.abspath("../../.."))

# %%
# Cell 1: imports & setup
import os, time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gc

gc.enable()

import torch
from torch.utils.data import DataLoader
from sklearn.model_selection import KFold
from sklearn.metrics import root_mean_squared_error

from src.config import EXP_CONFIGS
from src.utils import set_seed, save_config




main_folder = "../../.."
data_csv = os.path.join(main_folder, "data", "train.csv")
img_folder = os.path.join(main_folder, "data", "train")
out_dir = os.path.join(main_folder, "outputs","extra","exp12_effB1_StrongAug384_BS12" "exp12_FiLM_EfficientNetB1_ExternalModulationFeezeBackbone")   # 

df = pd.read_csv(data_csv)
cfg = EXP_CONFIGS["exp12_film"]   # define in config
cfg["name"] = "exp12_film_fusion_ExternalModulation_FreezeBackbone_EffB1"
cfg["backbone"] = "efficientnet_b1"
cfg["img_size"] = 384
cfg["aug"] = "strong"
cfg["batch_size"] = 12

TARGET = "Pawpularity"
tab_cols = [c for c in df.columns if c not in ["Id", TARGET]]

os.makedirs(out_dir, exist_ok=True)
save_config(cfg, out_dir)
set_seed(cfg["seed"])
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import root_mean_squared_error
from src.train import run_single_fold

kf = KFold(n_splits=cfg["n_splits"], shuffle=True, random_state=cfg["seed"])
oof_pred = np.zeros(len(df))
oof_true = df[TARGET].values
fold_index = np.full(len(df), -1, dtype=int)
fold_rmse = []

start_all = time.time()
for fold, (tr_idx, val_idx) in enumerate(kf.split(df), start=1):
    print(f"\n=== {cfg['name']}: Fold {fold} ===")
    train_df = df.iloc[tr_idx].reset_index(drop=True)
    val_df   = df.iloc[val_idx].reset_index(drop=True)

    best_rmse, val_preds, val_targets, val_ids = run_single_fold(
    fold=fold,
    train_df=train_df,
    val_df=val_df,
    img_folder=img_folder,
    cfg=cfg,
    out_dir=out_dir,
    device=device,
    mode="film_stack_EffB4",   # <--- use FiLMExternalModulation    branch
    tab_cols=tab_cols,
    workers=16,
    pin_memory=True,
    persistent_workers=True,
    freeze_backbone=True,
)

    oof_pred[val_idx] = val_preds
    fold_index[val_idx] = fold
    fold_rmse.append(best_rmse)
    print(f"Fold {fold} best RMSE: {best_rmse:.4f}")

all_sec = time.time() - start_all
print(f"\nTotal training time: {int(all_sec//60)}m {int(all_sec%60)}s")
# final metrics + OOF with fold column
oof_rmse = root_mean_squared_error(oof_true, oof_pred)
fold_rmse = np.array(fold_rmse)
print(f"\nOOF RMSE: {oof_rmse:.4f}")
print(f"Fold RMSEs: {fold_rmse.tolist()}  Mean={fold_rmse.mean():.4f}  Std={fold_rmse.std():.4f}")

oof_df = pd.DataFrame({
    "Id": df["Id"],
    "fold": fold_index,     
    "ytrue": oof_true,
    "oof_pred": oof_pred,
})
oof_df["abs_err"] = (oof_df["ytrue"] - oof_df["oof_pred"]).abs()
oof_df.to_csv(os.path.join(out_dir, "oof_detail.csv"), index=False)
oof_df.sort_values("abs_err", ascending=False).head(50).to_csv(
    os.path.join(out_dir, "top50_errors.csv"), index=False
)

np.save(os.path.join(out_dir, "oof_pred.npy"), oof_pred)
np.save(os.path.join(out_dir, "fold_rmse.npy"), fold_rmse)
with open(os.path.join(out_dir, "metrics.txt"), "w") as f:
    f.write(f"OOF_RMSE: {oof_rmse:.4f}\n")
    f.write(f"Fold_RMSE: {fold_rmse.tolist()}\nMean: {fold_rmse.mean():.4f}\nStd: {fold_rmse.std():.4f}\n")
# Out:
# === exp12_film_fusion_ExternalModulation_FreezeBackbone_EffB1: Fold 1 ===
# Epoch 1/10 | Fold 1 | Train[MSE]: RMSE=36.7866 | ValRMSE: 32.1499
# Epoch 2/10 | Fold 1 | Train[MSE]: RMSE=25.3371 | ValRMSE: 26.7297
# Epoch 3/10 | Fold 1 | Train[MSE]: RMSE=23.1722 | ValRMSE: 26.0112
# Epoch 4/10 | Fold 1 | Train[MSE]: RMSE=22.8623 | ValRMSE: 25.6557
# Epoch 5/10 | Fold 1 | Train[MSE]: RMSE=22.5328 | ValRMSE: 25.3085
# Epoch 6/10 | Fold 1 | Train[MSE]: RMSE=22.2630 | ValRMSE: 24.8660
# Epoch 7/10 | Fold 1 | Train[MSE]: RMSE=22.2981 | ValRMSE: 24.5698
# Epoch 8/10 | Fold 1 | Train[MSE]: RMSE=21.8927 | ValRMSE: 24.4395
# Epoch 9/10 | Fold 1 | Train[MSE]: RMSE=22.1795 | ValRMSE: 24.6181
# Epoch 10/10 | Fold 1 | Train[MSE]: RMSE=22.0388 | ValRMSE: 24.3676
# Fold 1 best RMSE: 24.3676
#
# === exp12_film_fusion_ExternalModulation_FreezeBackbone_EffB1: Fold 2 ===
# Epoch 1/10 | Fold 2 | Train[MSE]: RMSE=37.1252 | ValRMSE: 30.9729
# Epoch 2/10 | Fold 2 | Train[MSE]: RMSE=25.5555 | ValRMSE: 25.4970
# Epoch 3/10 | Fold 2 | Train[MSE]: RMSE=23.3004 | ValRMSE: 24.9690
# Epoch 4/10 | Fold 2 | Train[MSE]: RMSE=22.9030 | ValRMSE: 24.1069
# Epoch 5/10 | Fold 2 | Train[MSE]: RMSE=22.6347 | ValRMSE: 23.4812
# Epoch 6/10 | Fold 2 | Train[MSE]: RMSE=22.3557 | ValRMSE: 23.4133
# Epoch 7/10 | Fold 2 | Train[MSE]: RMSE=22.1247 | ValRMSE: 23.1871
# Epoch 8/10 | Fold 2 | Train[MSE]: RMSE=22.0965 | ValRMSE: 23.2707
# Epoch 9/10 | Fold 2 | Train[MSE]: RMSE=21.9361 | ValRMSE: 23.2066
# Epoch 10/10 | Fold 2 | Train[MSE]: RMSE=22.0258 | ValRMSE: 23.0525
# Fold 2 best RMSE: 23.0525
#
# === exp12_film_fusion_ExternalModulation_FreezeBackbone_EffB1: Fold 3 ===
# Epoch 1/10 | Fold 3 | Train[MSE]: RMSE=37.1842 | ValRMSE: 30.7220
# Epoch 2/10 | Fold 3 | Train[MSE]: RMSE=25.4491 | ValRMSE: 24.6534
# Epoch 3/10 | Fold 3 | Train[MSE]: RMSE=23.3568 | ValRMSE: 24.0826
# Epoch 4/10 | Fold 3 | Train[MSE]: RMSE=22.9697 | ValRMSE: 23.5470
# Epoch 5/10 | Fold 3 | Train[MSE]: RMSE=22.8033 | ValRMSE: 23.1368
# Epoch 6/10 | Fold 3 | Train[MSE]: RMSE=22.4285 | ValRMSE: 22.7402
# Epoch 7/10 | Fold 3 | Train[MSE]: RMSE=22.1630 | ValRMSE: 22.5666
# Epoch 8/10 | Fold 3 | Train[MSE]: RMSE=22.1375 | ValRMSE: 22.7335
# Epoch 9/10 | Fold 3 | Train[MSE]: RMSE=22.0787 | ValRMSE: 22.5287
# Epoch 10/10 | Fold 3 | Train[MSE]: RMSE=22.1436 | ValRMSE: 22.3271
# Fold 3 best RMSE: 22.3271
#
# === exp12_film_fusion_ExternalModulation_FreezeBackbone_EffB1: Fold 4 ===
# Epoch 1/10 | Fold 4 | Train[MSE]: RMSE=36.4706 | ValRMSE: 30.4288
# Epoch 2/10 | Fold 4 | Train[MSE]: RMSE=24.8767 | ValRMSE: 24.9580
# Epoch 3/10 | Fold 4 | Train[MSE]: RMSE=23.3082 | ValRMSE: 24.2024
# Epoch 4/10 | Fold 4 | Train[MSE]: RMSE=22.7611 | ValRMSE: 23.8480
# Epoch 5/10 | Fold 4 | Train[MSE]: RMSE=22.3668 | ValRMSE: 23.3428
# Epoch 6/10 | Fold 4 | Train[MSE]: RMSE=22.2129 | ValRMSE: 23.4416
# Epoch 7/10 | Fold 4 | Train[MSE]: RMSE=22.0988 | ValRMSE: 22.9302
# Epoch 8/10 | Fold 4 | Train[MSE]: RMSE=21.9190 | ValRMSE: 22.7967
# Epoch 9/10 | Fold 4 | Train[MSE]: RMSE=21.7796 | ValRMSE: 22.8002
# Epoch 10/10 | Fold 4 | Train[MSE]: RMSE=21.8973 | ValRMSE: 22.6737
# Fold 4 best RMSE: 22.6737
#
# === exp12_film_fusion_ExternalModulation_FreezeBackbone_EffB1: Fold 5 ===
# Epoch 1/10 | Fold 5 | Train[MSE]: RMSE=37.2966 | ValRMSE: 31.7767
# Epoch 2/10 | Fold 5 | Train[MSE]: RMSE=25.6176 | ValRMSE: 26.1036
# Epoch 3/10 | Fold 5 | Train[MSE]: RMSE=23.3828 | ValRMSE: 25.1855
# Epoch 4/10 | Fold 5 | Train[MSE]: RMSE=22.9505 | ValRMSE: 24.8437
# Epoch 5/10 | Fold 5 | Train[MSE]: RMSE=22.6779 | ValRMSE: 24.1388
# Epoch 6/10 | Fold 5 | Train[MSE]: RMSE=22.3558 | ValRMSE: 23.8600
# Epoch 7/10 | Fold 5 | Train[MSE]: RMSE=22.1851 | ValRMSE: 23.6737
# Epoch 8/10 | Fold 5 | Train[MSE]: RMSE=22.0158 | ValRMSE: 23.7865
# Epoch 9/10 | Fold 5 | Train[MSE]: RMSE=21.8179 | ValRMSE: 23.4722
# Epoch 10/10 | Fold 5 | Train[MSE]: RMSE=21.9370 | ValRMSE: 23.4526
# Fold 5 best RMSE: 23.4526
#
# Total training time: 16m 34s
#
# OOF RMSE: 23.1855
# Fold RMSEs: [24.36756134033203, 23.052539825439453, 22.32708740234375, 22.673715591430664, 23.452550888061523]  Mean=23.1747  Std=0.7049

# %%
#oof rmse = 23.8348
import pandas
df = pd.read_csv(out_dir+"/oof_detail.csv")
fold_rmse = []

for fold in range(1, 6):
    sub = df[df.fold == fold]
    rmse = ((sub.ytrue - sub.oof_pred)**2).mean() ** 0.5
    fold_rmse.append(rmse)
    print(f"Fold {fold} OOF RMSE: {rmse:.4f} (n={len(sub)})")
# Out:
# Fold 1 OOF RMSE: 24.3676 (n=1983)
# Fold 2 OOF RMSE: 23.0525 (n=1983)
# Fold 3 OOF RMSE: 22.3271 (n=1982)
# Fold 4 OOF RMSE: 22.6737 (n=1982)
# Fold 5 OOF RMSE: 23.4526 (n=1982)

# %%
from src.plot import plot_train_val_history
plot_train_val_history(out_dir, folds=[1,2,3,4,5], title_prefix="Exp12 FiLM Layer after Freeze BackboneFeature Extraction EfficientNetB4")

# %%
from src.plot import plot_train_val_history
out_dir1 = os.path.join("../../..", "outputs", "exp4")
plot_train_val_history(out_dir1, folds=[1,2,3,4,5], title_prefix="Exp4 FeatureConcatFusion EfficientNetB4")

# %%
from src.plot import plot_compare_two_experiments
plot_compare_two_experiments(out_dir, out_dir1,folds=[1,2,3,4,5], label_a="Exp12 FiLM Layer after Freeze BackboneFeature Extraction EfficientNetB4", label_b="Exp4 FeatureConcatFusion EfficientNetB4")

# %%
from src.plot import plot_all_folds_history
plot_all_folds_history(out_dir, folds=[1,2,3,4,5], title_prefix="Exp12 FiLM EfficientNetB4")

# %%
#  Inspect worst error rows

errors_path = os.path.join(out_dir, "top50_errors.csv")
err_df = pd.read_csv(errors_path)
err_df.head()
# Out:
#                                  Id  fold  ytrue   oof_pred    abs_err
# 0  587c58bb1bc45cd903c18a3554b83c72     5    100   7.663497  92.336503
# 1  1dc00c8c6be7939ead0f0005a90f1c7b     1    100   8.048211  91.951789
# 2  eafe4e31237c5b6fd0957e80418c36b0     1    100   9.880229  90.119771
# 3  c1e5610529465ff5b9e337f205b7209a     5    100  11.641934  88.358066
# 4  76769dbee1699e04ae1befa3128db7d6     2    100  11.989654  88.010346

# %%
import os
import pandas as pd
from src.plot import (
   plot_oof_true_pred_lines,
    show_images_grid,
)

# Load OOF detail and top-errors
oof_df = pd.read_csv(os.path.join(out_dir, "oof_detail.csv"))
err_df = pd.read_csv(os.path.join(out_dir, "top50_errors.csv"))

# Plot
plot_oof_true_pred_lines(oof_df, title_prefix="Exp12")

# %%
from src.plot import compare_oof_by_bins
bins = [0, 20, 40, 60, 80, 100]

df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
    oof_path_a=os.path.join(out_dir, "oof_detail.csv"),
    oof_path_b=os.path.join(out_dir1, "oof_detail.csv"),
    bins=bins,
    label_a="Exp12_FiLM_Eff_B4 Frozen image backbone and  External layer FiLM Fusion",
    label_b="Exp4_FeatureConcat EffB4 Fusion",
    title_prefix="EfficientNet",
)
# Out:
# Exp12_FiLM_Eff_B4 Frozen image backbone and  External layer FiLM Fusion OOF RMSE: 23.185518563553238
# Exp4_FeatureConcat EffB4 Fusion OOF RMSE: 19.90331621767278
# ΔRMSE (Exp4_FeatureConcat EffB4 Fusion - Exp12_FiLM_Eff_B4 Frozen image backbone and  External layer FiLM Fusion): -3.2822023458804566

# %%
df_bins.head()
# Out:
#          bin  count  \
# 0    (0, 20]   1417
# 1   (20, 40]   5119
# 2   (40, 60]   2088
# 3   (60, 80]    727
# 4  (80, 100]    561
#
#    Exp12_FiLM_Eff_B4 Frozen image backbone and  External layer FiLM Fusion_rmse  \
# 0                                          22.062719
# 1                                          10.181232
# 2                                          18.782204
# 3                                          37.959720
# 4                                          64.361116
#
#    Exp4_FeatureConcat EffB4 Fusion_rmse  rmse_diff  \
# 0                             23.561754   1.499035
# 1                             11.605182   1.423950
# 2                             16.538259  -2.243945
# 3                             30.127592  -7.832128
# 4                             46.623998 -17.737118
#
#                                               winner
# 0  Exp12_FiLM_Eff_B4 Frozen image backbone and  E...
# 1  Exp12_FiLM_Eff_B4 Frozen image backbone and  E...
# 2             Exp4_FeatureConcat EffB4 Fusion_better
# 3             Exp4_FeatureConcat EffB4 Fusion_better
# 4             Exp4_FeatureConcat EffB4 Fusion_better
