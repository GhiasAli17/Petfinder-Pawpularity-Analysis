# Epoch 3/10 | Fold 5 | Train[MSE]: RMSE=20.6151 | ValRMSE: 20.5108
# Epoch 4/10 | Fold 5 | Train[MSE]: RMSE=19.7698 | ValRMSE: 18.7279
# Epoch 5/10 | Fold 5 | Train[MSE]: RMSE=18.1448 | ValRMSE: 17.9656
# Epoch 6/10 | Fold 5 | Train[MSE]: RMSE=17.0559 | ValRMSE: 17.7192
# Epoch 7/10 | Fold 5 | Train[MSE]: RMSE=16.2579 | ValRMSE: 17.8345
# Epoch 8/10 | Fold 5 | Train[MSE]: RMSE=15.7351 | ValRMSE: 17.7612
# Epoch 9/10 | Fold 5 | Train[MSE]: RMSE=15.2987 | ValRMSE: 17.7618
# Epoch 10/10 | Fold 5 | Train[MSE]: RMSE=15.0599 | ValRMSE: 17.7915
# Fold 5 best RMSE: 17.7192
#
# Total training time: 250m 56s
#
# OOF RMSE: 17.7630
# Fold RMSEs: [17.576457977294922, 18.109844207763672, 18.078475952148438, 17.317974090576172, 17.71920394897461]  Mean=17.7604  Std=0.3015

# %%
import pandas
df = pd.read_csv(out_dir+"/oof_detail.csv")
fold_rmse = []

for fold in range(1, 6):
    sub = df[df.fold == fold]
    rmse = ((sub.ytrue - sub.oof_pred)**2).mean() ** 0.5
    fold_rmse.append(rmse)
    print(f"Fold {fold} OOF RMSE: {rmse:.4f} (n={len(sub)})")
# Out:
# Fold 1 OOF RMSE: 17.5765 (n=1983)
# Fold 2 OOF RMSE: 18.1098 (n=1983)
# Fold 3 OOF RMSE: 18.0785 (n=1982)
# Fold 4 OOF RMSE: 17.3180 (n=1982)
# Fold 5 OOF RMSE: 17.7192 (n=1982)

# %%
from src.plot import plot_all_folds_history
plot_all_folds_history(out_dir, folds=[1,2,3,4,5], title_prefix="exp3_swin_256_strong")

# %%
#  Inspect worst error rows

errors_path = os.path.join(out_dir, "top50_errors.csv")
err_df = pd.read_csv(errors_path)
err_df.head()
# Out:
#                                  Id  fold  ytrue   oof_pred    abs_err
# 0  e638853bdec13e6cc76b69f169b34740     4     96  23.268894  72.731106
# 1  48a66727373de4e7fa7bb3331cd9acc8     2     96  23.528601  72.471399
# 2  941e532a21f7edb21766e88a15e588cb     2    100  30.609081  69.390919
# 3  f7903a7d6be4a636f8c28fd23b4951ec     1    100  30.843290  69.156710
# 4  4435d6f98ad72782ca0cf61f946b016d     2    100  31.243841  68.756159

# %%
import os
import pandas as pd
from src.plot import (
   plot_oof_true_pred_lines,
    show_images_grid,
)

# Load OOF detail and top-errors
oof_df = pd.read_csv(os.path.join(out_dir, "oof_detail.csv"))
err_df = pd.read_csv(os.path.join(out_dir, "top50_errors.csv"))

# Plots
plot_oof_true_pred_lines(oof_df, title_prefix="exp3_swin_256_strong")

# %%
from src.plot import compare_oof_by_bins
bins = [0, 20, 40, 60, 80, 100]

df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
    oof_path_a="../../outputs/extra/exp3_swin_256_lite/oof_detail.csv",
    oof_path_b="../../outputs/extra/exp3_swin_256_strong/oof_detail.csv",
    bins=bins,
    label_a="exp3_swin_256_lite",
    label_b="exp3_swin_256_strong",
    title_prefix="swin lite Aug vs Swin StrongAug",
)
# Out:
# exp3_swin_256_lite OOF RMSE: 17.863752509333363
# exp3_swin_256_strong OOF RMSE: 17.872816628403204
# ΔRMSE (exp3_swin_256_strong - exp3_swin_256_lite): 0.009064119069840615

# %%
df_bins.head()
# Out:
#          bin  count  exp3_swin_256_lite_rmse  exp3_swin_256_strong_rmse  \
# 0    (0, 20]   1417                24.803805                  24.055602
# 1   (20, 40]   5119                10.285063                   9.897319
# 2   (40, 60]   2088                13.267305                  13.928721
# 3   (60, 80]    727                24.725945                  25.328478
# 4  (80, 100]    561                40.885352                  41.653878
#
#    rmse_diff                       winner
# 0  -0.748203  exp3_swin_256_strong_better
# 1  -0.387744  exp3_swin_256_strong_better
# 2   0.661416    exp3_swin_256_lite_better
# 3   0.602533    exp3_swin_256_lite_better
# 4   0.768526    exp3_swin_256_lite_better

# %%
# Images of worst errors
img_folder = os.path.join(main_folder, "data", "train")
show_images_grid(err_df, img_folder, n=12, title_prefix="exp3_swin_256_strongNoFusion_worst errors")

# %%
# Images of worst errors
img_folder = os.path.join(main_folder, "data", "train")
show_images_grid(oof_df, img_folder, n=12, title_prefix="exp3_swin_256_strong_NoFusion_first 12 images")
