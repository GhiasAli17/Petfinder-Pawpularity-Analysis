# %% [markdown]
# ### Here the high resolution + strong augmention and low resolution + lite augmentation are compared by EfficientB0 and EfficientB4 , while all the other configurations remain same.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.insert(0, os.path.abspath("../.."))

# %% [markdown]
# ### 1. EfficientB0 Model with lite and strong augmentation

# %%
from src.plot import compare_oof_by_bins
bins = [0, 20, 40, 60, 80, 100]

df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
    oof_path_a="../../outputs/exp2/oof_detail.csv",
    oof_path_b="../../outputs/extra/exp2_384_effB0_strongAug/oof_detail.csv",
    bins=bins,
    label_a="Exp2_Eff0_256_LiteAug",
    label_b="Exp2_Eff0_384_Strong",
    title_prefix="EfficientNet lite vs Strong",
)
# Out:
# Exp2_Eff0_256_LiteAug OOF RMSE: 19.177387932516293
# Exp2_Eff0_384_Strong OOF RMSE: 18.868141449310343
# ΔRMSE (Exp2_Eff0_384_Strong - Exp2_Eff0_256_LiteAug): -0.30924648320594983

# %%
df_bins.head()
# Out:
#          bin  count  Exp2_Eff0_256_LiteAug_rmse  Exp2_Eff0_384_Strong_rmse  \
# 0    (0, 20]   1417                   24.106148                  22.923950
# 1   (20, 40]   5119                   10.851486                   9.420940
# 2   (40, 60]   2088                   14.386820                  14.841398
# 3   (60, 80]    727                   27.984539                  29.151475
# 4  (80, 100]    561                   46.588225                  47.241823
#
#    rmse_diff                        winner
# 0  -1.182198   Exp2_Eff0_384_Strong_better
# 1  -1.430546   Exp2_Eff0_384_Strong_better
# 2   0.454578  Exp2_Eff0_256_LiteAug_better
# 3   1.166936  Exp2_Eff0_256_LiteAug_better
# 4   0.653598  Exp2_Eff0_256_LiteAug_better

# %% [markdown]
# ### 2. EfficientNetB4

# %%
df_bins, rmse3_all, rmse5_all, gap = compare_oof_by_bins(
    oof_path_a="../../outputs/extra/exp8_256_effB4_liteAug/oof_detail.csv",
    oof_path_b="../../outputs/exp8/oof_detail.csv",
    
    bins=bins,
    label_a="Exp2_Eff4_256_LiteAug",
    label_b="Exp2_Eff4_384_Strong",
    title_prefix="EfficientNetB4 lite vs Strong",
)
# Out:
# Exp2_Eff4_256_LiteAug OOF RMSE: 19.069219459958898
# Exp2_Eff4_384_Strong OOF RMSE: 18.682241951546622
# ΔRMSE (Exp2_Eff4_384_Strong - Exp2_Eff4_256_LiteAug): -0.38697750841227574

# %%
df_bins.head()
# Out:
#          bin  count  Exp2_Eff4_384_Strong_rmse  Exp2_Eff4_256_LiteAug_rmse  \
# 0    (0, 20]   1417                  24.426563                   22.815533
# 1   (20, 40]   5119                  10.000162                    8.891782
# 2   (40, 60]   2088                  13.779298                   14.525071
# 3   (60, 80]    727                  28.393745                   28.761188
# 4  (80, 100]    561                  47.474817                   47.678782
#
#    rmse_diff                        winner
# 0  -1.611030  Exp2_Eff4_256_LiteAug_better
# 1  -1.108379  Exp2_Eff4_256_LiteAug_better
# 2   0.745773   Exp2_Eff4_384_Strong_better
# 3   0.367443   Exp2_Eff4_384_Strong_better
# 4   0.203964   Exp2_Eff4_384_Strong_better
