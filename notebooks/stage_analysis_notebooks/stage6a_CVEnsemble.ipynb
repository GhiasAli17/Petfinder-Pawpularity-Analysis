# %% [markdown]
# > In this stage, the single swin best fold model vs 5 folds ensemble predictions are compared. The 5‑fold SWIN ensemble did not help to capture different pattern as all the fold models are having the similar type of error on the extreme regions

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.insert(0, os.path.abspath("../.."))

# %% [markdown]
# ### 1. EfficientB0_256_LiteAug vs SWIN_384_StrongAug

# %%
from src.plot import compare_oof_by_bins_multi
import pandas as pd
bins = [0, 20, 40, 60, 80, 100]

test_cv_df = pd.read_csv("../../outputs/exp10/test_cv_df.csv")
summary, overall = compare_oof_by_bins_multi(
    test_cv_df,
    bins=bins,
    y_col="ytrue",
    pred_cols={
        "Exp5_swin_earlyFusionSingleBestFold_Testdata": "fold3_pred",
        "Exp10_swin_5fold ensemble Test Data": "avg",
    },
    title_prefix="SWIN_EarlyFusionBestFold vs SWIN_FoldEnsemble"
)
# Out:
# Exp5_swin_earlyFusionSingleBestFold_Testdata OOF RMSE: 17.6955
# Exp10_swin_5fold ensemble Test Data OOF RMSE: 17.4983

# %%
summary.head()
# Out:
#          bin  count  Exp5_swin_earlyFusionSingleBestFold_Testdata_rmse  \
# 0    (0, 20]    428                                          24.374609
# 1   (20, 40]   1530                                          10.477512
# 2   (40, 60]    633                                          13.310433
# 3   (60, 80]    217                                          24.103423
# 4  (80, 100]    166                                          40.388971
#
#    Exp10_swin_5fold ensemble Test Data_rmse
# 0                                 23.614473
# 1                                  9.137428
# 2                                 12.694995
# 3                                 25.276015
# 4                                 42.761468
